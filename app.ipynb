# %%
import random

# %%
a_i = " abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"
a = {char: idx for idx, char in enumerate(" abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!")}
char_space = len(a) - 1

def word(length:int) -> list[int]:
    res:list[int] = []
    for _ in range(length):
        res.append( random.randint(0, char_space)) 
    return res

def word_to_arr(word:str) -> list[int]:
    return  [ a[letter]  for letter in word  ]


def generate_population(size:int, length:int) ->  list[int]:
    res:list[int] = [] 
    for _  in  range(size):
        res.append(word(length))
    return res

def translate(word:list[int]) -> str:
    res : str = "" 
    for letter in  word :  
        res +=  a_i[letter] 
    return res

def fitness_reference(target : str) -> int:
    res:list[int] = []
    for letter in target:
        res.append( max( char_space - a[letter], a[letter]))
    return res 

def  fitness(word:list[int],reference: list[int], target : str):
    res : int = 0
    for letter, tar, ref in zip(word, target, reference):
        res += ref - abs( letter - a[tar])
    return res

def cross_over(word1 : list[int], word2 :list[int])-> list[list]:
    p = random.randint(1,len(word1) - 1)
    return [ word1[:p]+word2[p:],  word2[:p]+word1[p:]]

def mutation(word: list[int])->list[int]:
    mut = []
    for letter in word:
        new_letter = letter + int(random.normalvariate())
        if  new_letter > char_space :  new_letter = char_space 
        if  new_letter < 0 :  new_letter = 0
        mut.append(new_letter)
    return mut

def select( population : list[list],  reference : list[int], target:str)->list[int]:
    return random.choices(population, weights= [ fitness( _word , reference ,target) for _word in population ], k=2)

def eval(target: str, gen_size:int):

    population =  generate_population(gen_size, len(target))
    reference  = fitness_reference(target)
    tager_arr =  word_to_arr(target)
    for i  in range(300):
        
        population = sorted(
            population,
            key=lambda x : fitness(x, reference, target),
            reverse=True
        )
        
        target_fitness = fitness(tager_arr, reference, target)
        current_fitness = fitness(population[0], reference, target)

        print( i,
              f"{current_fitness}/{target_fitness}: ", 
              translate(population[0]))
        
        if current_fitness ==  target_fitness : 
            print ("FOUND !")
            break

        next_gen:list[int] = population[0:2]

        for _ in range(2, len(population), 2): 
            offspring_a, offspring_b =  cross_over(next_gen[0], next_gen[1])
            offspring_a =  mutation(offspring_a)
            offspring_b =  mutation(offspring_b)
            next_gen+= [offspring_a, offspring_b]
        population = next_gen

eval( "Genetic Algorithm" , 100)
# Out:
# 0 610/856:  GCSziqlUIFfdze yg
# 1 653/856:  zmoyiqlUIFfdzeaxh
# 2 658/856:  zkoxhqjTIGfdzeavg
# 3 663/856:  BknxhriTIGfdyeaug
# 4 668/856:  zkoxipiSIDgdyeaug
# 5 678/856:  DkowjpiRHCgdyebug
# 6 686/856:  DjnwjpiRGCgdwecsg
# 7 692/856:  EknvlphQFCgdwecsg
# 8 700/856:  ElnvnogPFBgewfetg
# 9 709/856:  FlnvongPFBgftfesh
# 10 716/856:  GlntpofPFBggtgfsh
# 11 722/856:  GlntqmfOFBggsgfrh
# 12 730/856:  GlnsrmfOGBgirgfsm
# 13 733/856:  GmnsrneNFzgirhftm
# 14 738/856:  GmnqrmdNGzgiqifqn
# 15 746/856:  HimrsmeKEzgkrieqn
# 16 750/856:  GkootleKEzhkqifpn
# 17 754/856:  GknptleKEygkqifom
# 18 761/856:  GjnntleJCxgkqifom
# 19 764/856:  GjnltleKCwhlrifom
# 20 769/856:  HinktldHCwgmrifqm
# 21 776/856:  GgnktldGBwgnrifpm
# 22 781/856:  GfnjtjeGBwforiemm
# 23 786/856:  GfnhtjdGBugmqihnm
# 24 788/856:  GfmgtjdGBugmrihmm
# 25 791/856:  GfnguieFBugnrjhkm
# 26 794/856:  GfngtidGBugnrihjm
# 27 797/856:  GdmgtjdGArgkriljm
# 28 802/856:  GemftjeGAqgnriljm
# 29 805/856:  GenhticFBpgnriljm
# 30 810/856:  GdmetidFAnfnrimhm
# 31 811/856:  GenetidFzngnqimhm
# 32 812/856:  GenetidGAmforjmhm
# 33 816/856:  GenetidEAmfnriohm
# 34 816/856:  GenetidEAmfnriohm
# 35 816/856:  GenetidEAmfnriohm
# 36 816/856:  GenetidEAmfnriohm
# 37 817/856:  GenetidEAmhoriohm
# 38 819/856:  FenesidCBlgorhqhm
# 39 822/856:  GeoetidCBlgorhshm
# 40 823/856:  GemetidCAlgorishl
# 41 823/856:  GemetidCAlgorishl
# 42 824/856:  GemeticDAlgorithl
# 43 824/856:  GemeticDAlgorithl
# 44 824/856:  GemeticDAlgorithl
# 45 825/856:  GemeticBAlgoqitim
# 46 825/856:  GemeticBAlgoqitim
# 47 825/856:  GemeticBAlgoqitim
# 48 825/856:  GemeticBAlgoqitim
# 49 826/856:  GeneticBAlgoqitim
# 50 826/856:  GeneticBAlgoqitim
# 51 827/856:  GdneticzAlgoqiuhm
# 52 828/856:  GenetibyAlgpqithm
# 53 828/856:  GenetibyAlgpqithm
# 54 829/856:  GeoeticxAlgosiuhm
# 55 831/856:  GeoeticvAlgpriuhm
# 56 834/856:  HeoetictAlgorithm
# 57 834/856:  HeoetictAlgorithm
# 58 834/856:  HeoetictAlgorithm
# 59 834/856:  HeoetictAlgorithm
# 60 834/856:  HeoetictAlgorithm
# 61 834/856:  HeoetictAlgorithm
# 62 834/856:  HeoetictAlgorithm
# 63 834/856:  HeoetictAlgorithm
# 64 836/856:  GfoeticrAlgorithm
# 65 836/856:  GfoeticrAlgorithm
# 66 836/856:  GfoeticrAlgorithm
# 67 836/856:  GfoeticrAlgorithm
# 68 836/856:  GfoeticrAlgorithm
# 69 836/856:  GfoeticrAlgorithm
# 70 836/856:  GfoeticrAlgorithm
# 71 837/856:  GfoesicpAlgorithm
# 72 837/856:  GfoesicpAlgorithm
# 73 838/856:  GeoevicnAlgoritgm
# 74 839/856:  GeoevibmAlgorithm
# 75 839/856:  GeoevibmAlgorithm
# 76 839/856:  GeoevibmAlgorithm
# 77 840/856:  GeofvibkAlgorithm
# 78 840/856:  GeofvibkAlgorithm
# 79 843/856:  GeofticjAlgorithn
# 80 843/856:  GeofticjAlgorithn
# 81 845/856:  GeoftichAlhorithm
# 82 845/856:  GeoftichAlhorithm
# 83 845/856:  GeoftichAlhorithm
# 84 846/856:  GenfthcgAlhorithm
# 85 847/856:  GeoeticfAlhoritim
# 86 847/856:  GeoeticfAlhoritim
# 87 847/856:  GeoeticfAlhoritim
# 88 847/856:  GeoeticfAlhoritim
# 89 847/856:  GeoeticfAlhoritim
# 90 847/856:  GeoeticfAlhoritim
# 91 848/856:  GeneticgAlgorithl
# 92 848/856:  GeneticgAlgorithl
# 93 848/856:  GeneticgAlgorithl
# 94 849/856:  GeneticeAlgoritjm
# 95 849/856:  GeneticeAlgoritjm
# 96 849/856:  GeneticeAlgoritjm
# 97 851/856:  GendticcAlgorithl
# 98 851/856:  GendticcAlgorithl
# 99 851/856:  GendticcAlgorithl
# 100 851/856:  GendticcAlgorithl
# 101 852/856:  GenetibaAmhorithm
# 102 852/856:  GenetibaAmhorithm
# 103 853/856:  Genetib Amhorithm
# 104 853/856:  Genetib Amhorithm
# 105 854/856:  Genetic Alhoqithm
# 106 854/856:  Genetic Alhoqithm
# 107 854/856:  Genetic Alhoqithm
# 108 854/856:  Genetic Alhoqithm
# 109 854/856:  Genetic Alhoqithm
# 110 856/856:  Genetic Algorithm
# FOUND !
